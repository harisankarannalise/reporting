# %%
import glob
import pandas as pd
import json
import base64
from PIL import Image
import io
import numpy as np 
from jinja2 import Environment, FileSystemLoader, select_autoescape
import argparse
import os

def proc(f):
     return dict([(finding['label'], finding['predictionProbability']) for g in f['classification']['findings']['vision']['study']['classifications']['relevant'] for finding in g['findings']] + 
                 [(finding['label'], finding['predictionProbability']) for finding in f['classification']['findings']['vision']['study']['classifications']['irrelevant']])
def get_threshold(f):
     return dict([(finding['label'], finding['predictionThreshold']) for g in f['classification']['findings']['vision']['study']['classifications']['relevant'] for finding in g['findings']] + 
                 [(finding['label'], finding['predictionThreshold']) for finding in f['classification']['findings']['vision']['study']['classifications']['irrelevant']])

def block_reduce(image, block_size, func):
    rows, cols = image.shape
    block_rows, block_cols = block_size
    reduced_rows = rows // block_rows
    reduced_cols = cols // block_cols
    reduced_image = np.empty((reduced_rows, reduced_cols))

    for i in range(reduced_rows):
        for j in range(reduced_cols):
            block = image[i * block_rows: (i + 1) * block_rows, j * block_cols: (j + 1) * block_cols]
            reduced_image[i, j] = func(block)

    return reduced_image

# %%
input_dir = 'cxrjsons'
output_dir = 'reports'
paths = glob.glob(f'{input_dir}/*.json')
# Create output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
data = []
ancillary_data = {}
for path in paths:
    with open(path) as f:
        raw_data = json.load(f)
        d = proc(raw_data)
        filtered_images = []
        for image in raw_data['classification']['findings']['vision']['images']:
            filtered_images.append({k: v for k, v in image.items() if k in ['imageInstanceUid', 'viewPosition']})
        viewpositions = [d['viewPosition'] for d in filtered_images]
        filtered_image_uids = [d['imageInstanceUid'] for d in filtered_images if d['viewPosition'] in {'AP', 'PA'}]

        pooled_segmentations3x2 = {}
        pooled_segmentations2x2 = {}
        pooled_lateralities = {}

        for filtered_image in filtered_image_uids:
            for key, png_bytes in raw_data['segmentation'][filtered_image].items():
                # Decode the PNG bytes
                decoded_image = base64.b64decode(png_bytes)

                # Open the image using PIL
                image = Image.open(io.BytesIO(decoded_image))
                image = np.array(image)[:,:,1]

                # 3 to allow it to be chopped into upper, middle, lower
                pooled_image = block_reduce(image, (image.shape[0]//3, image.shape[1]//2), np.max)
                if key not in pooled_segmentations3x2:                
                    pooled_segmentations3x2[key] = pooled_image
                else:
                    pooled_segmentations3x2[key] += pooled_image
                    
                # 3 to allow it to be chopped into upper, middle, lower
                pooled_image = block_reduce(image, (image.shape[0]//2, image.shape[1]//2), np.max)
                if key not in pooled_segmentations2x2:                
                    pooled_segmentations2x2[key] = pooled_image
                else:
                    pooled_segmentations2x2[key] += pooled_image

                    
            for key, side in raw_data['laterality'][filtered_image].items():
                if side == 'RIGHT':
                    pooled_image = np.array([1,0])
                elif side == 'LEFT':
                    pooled_image = np.array([0,1])
                elif side == 'BILATERAL':
                    pooled_image = np.array([1,1])
                elif side == 'NONE':
                    pooled_image = np.array([0,0])
                else:
                    raise Exception(f'{side} not recognized for {key} for {path}')
                
                if key not in pooled_lateralities:                
                    pooled_lateralities[key] = pooled_image
                else:
                    pooled_lateralities[key] += pooled_image

        for key, value in pooled_segmentations2x2.items():
            pooled_segmentations2x2[key] = (pooled_segmentations2x2[key] > 0)

        for key, value in pooled_segmentations3x2.items():
            pooled_segmentations3x2[key] = (pooled_segmentations3x2[key] > 0)
        
        for key, value in pooled_lateralities.items():
            pooled_lateralities[key] = (pooled_lateralities[key] > 0)

    

        
    d['accession'] = path.split('/')[-1].replace('.json', '')
    ancillary_data[d['accession'] ] = {'pooled_segmentations_3x2': pooled_segmentations3x2,'pooled_segmentations_2x2': pooled_segmentations2x2, 'pooled_lateralities': pooled_lateralities, 'viewpositions':viewpositions}
    data.append(d)
df = pd.DataFrame(data).set_index('accession')

# assume thresholds are consistent across all jsons! 
with open(path) as f:
    thresholds = pd.DataFrame(get_threshold(json.load(f)), index=['threshold']).transpose()

section_mapping = {}
for section, _df in pd.read_csv('fortis_spec.csv', index_col=0).groupby('Report Section'):
    slug = section.strip().lower().replace(' ','_')
    if slug not in section_mapping:
        section_mapping[slug] = []
    section_mapping[slug].extend(_df.index.tolist())
section_mapping['projection'] = ['lat', 'multifrontal']

# %%
pooled_segmentations2x2.keys()
# Out:
# dict_keys(['collapse_segmentation', 'humeral_lesion_segmentation', 'ngt_segmentation', 'internal_foreign_body_segmentation', 'scapular_lesion_segmentation', 'airspace_opacity_segmentation', 'pleural_mass_segmentation', 'clavicle_lesion_segmentation', 'pneumothorax_segmentation', 'cvc_segmentation', 'rib_lesion_segmentation', 'acute_rib_fracture_segmentation', 'effusion_segmentation', 'lesion_segmentation'])

# %%
def create_side_zone(arr):
    if arr.shape == (2,):
        if arr[0] == 1 and arr[1] == 0:
            return 'right'
        elif arr[0] == 0 and arr[1] == 1:
            return 'left'
        elif arr[0] == 1 and arr[1] == 1:
            return 'bilateral'
        elif arr[0] == 0 and arr[1] == 0:
            return None
    elif arr.shape == (2,2):
        coords = np.argwhere(arr)
        strings = [f"{'right' if x == 0 else 'left'} {'upper' if y == 0 else 'lower'}" for y,x in coords]
        if (len(strings)%2 == 0) and ('right upper' in strings and 'right lower' in strings):
            strings.remove('right upper')
            strings.remove('right lower')
            strings.append('right-sided')
        if (len(strings)%2 == 0) and ('left upper' in strings and 'left lower' in strings):
            strings.remove('left upper')
            strings.remove('left lower')
            strings.append('left-sided')
        if 'left-sided' in strings and 'right-sided' in strings:
            strings.remove('left-sided')
            strings.remove('right-sided')
            strings.append('bilateral')
        if 'left upper' in strings and 'right upper' in strings:
            strings.remove('left upper')
            strings.remove('right upper')
            strings.append('bilateral upper')
        if 'left lower' in strings and 'right lower' in strings:
            strings.remove('left lower')
            strings.remove('right lower')
            strings.append('bilateral lower')
        if len(strings) > 1:
            return ', '.join(strings[:-1]) + ' and ' + strings[-1] 
        return ', '.join(strings)
    elif arr.shape == (3,2):
        pass
    else:
        raise NotImplementedError(f'arr shape {arr.shape} not supported')

# %%
env = Environment(
    loader=FileSystemLoader('templates/'),
    autoescape=select_autoescape(['html', 'xml', 'jinja'])
)

bin_df = df > thresholds.values.transpose()
defaults = {'projection':'Frontal chest radiograph.',
            'technical_quality':'Satisfactory image quality.',
            'cardiomediastinal':'Cardiac silhouette within normal limits. Normal mediastinal and hilar contours.',
            'lung_parenchyma':'No significant parenchymal lung abnormality.',
            'pleural_space':'Normal pleural spaces.',
            'lines_and_tubes': "No lines or tubes identified.",
            'bones':'No bony abnormality.',
            'other':'No other findings.'}


for accession in bin_df.index:
    # get only positive columns
    bin_findings = bin_df.loc[accession]
    bin_findings['lat'] = 'LAT' in ancillary_data[accession]['viewpositions']
    bin_findings['multifrontal'] = ('LAT' not in ancillary_data[accession]['viewpositions']) and len(ancillary_data[accession]['viewpositions']) > 1
    positive_findings = bin_findings[bin_findings]
    
    laterality_texts = {key+'_laterality': create_side_zone(values) for key, values in ancillary_data[accession]['pooled_lateralities'].items()}
    zone2x2_texts = {key+'_zone2x2': create_side_zone(values) for key, values in ancillary_data[accession]['pooled_segmentations_2x2'].items()}
    # 1x2 is map but converted into left/right
    zone_to_laterality_texts = {key+'_laterality': create_side_zone((values.sum(axis=0)>0).astype(int)) for key, values in ancillary_data[accession]['pooled_segmentations_2x2'].items()}
    
    template_components = {}
    for template_name in env.list_templates():
        template_name = template_name.replace('.jinja', '')
        if template_name != 'base_report':
            template = env.get_template(template_name + '.jinja')
            output = template.render(**bin_findings, **laterality_texts, **zone2x2_texts, **zone_to_laterality_texts)
            # remove all empty lines (artifact of how my jinja templates are laid out)
            output = ' '.join([line.capitalize() for line in output.split('\n') if len(line)])
            # if the section has no relevant findings, use the default
            if template_name in section_mapping:
                if not any([finding in section_mapping[template_name] for finding in positive_findings.index]):
                    output = defaults[template_name]     
                elif template_name == 'lung_parenchyma':
                    print (positive_findings)
            template_components[template_name] = output


    template = env.get_template('base_report.jinja')
    output = template.render(**template_components)

    output_path = os.path.join(output_dir, f"{accession}.txt")
    with open(output_path, "w") as f:
        f.write(output)
    print (accession)
    print (output)
    print ('*******************************')
# Out:
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# Name: JPCNN008, dtype: bool
# JPCNN008
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN090, dtype: bool
# JPCLN090
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left lower zone. Focal well defined nodule(s) in the left lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta           True
# hyperinflation           True
# peribronchial_cuffing    True
# Name: JPCNN006, dtype: bool
# JPCNN006
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN027, dtype: bool
# JPCLN027
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right-sided zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# linear_atelectasis           True
# peribronchial_cuffing        True
# Name: JPCNN015, dtype: bool
# JPCNN015
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Atelectasis noted in the right lower lung.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# gastric_band                 True
# single_pulmonary_nodule      True
# Name: JPCLN074, dtype: bool
# JPCLN074
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# single_pulmonary_nodule      True
# Name: JPCLN029, dtype: bool
# JPCLN029
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                     True
# aortic_arch_calcification          True
# hyperinflation                     True
# interstitial_thickening_diffuse    True
# peribronchial_cuffing              True
# pulmonary_artery_enlargement       True
# scoliosis                          True
# Name: JPCLN053, dtype: bool
# JPCLN053
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Diffuse right fibrotic changes with preserved lung volume.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                 True
# aortic_arch_calcification      True
# focal_airspace_opacity         True
# multifocal_airspace_opacity    True
# patient_rotated                True
# single_pulmonary_nodule        True
# Name: JPCLN081, dtype: bool
# JPCLN081
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multifocal airspace opacities in the left lung. Focal airspace opacity in the left upper zone. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN019
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# calcified_granuloma          True
# hyperinflation               True
# single_pulmonary_nodule      True
# superior_mediastinal_mass    True
# Name: JPCLN076, dtype: bool
# JPCLN076
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# patient_rotated              True
# peribronchial_cuffing        True
# Name: JPCNN017, dtype: bool
# JPCNN017
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN004
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# multiple_pulmonary_masses    True
# single_pulmonary_nodule      True
# Name: JPCLN036, dtype: bool
# JPCLN036
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multiple lung lesions noted in the left lung. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# single_pulmonary_mass        True
# single_pulmonary_nodule      True
# Name: JPCLN011, dtype: bool
# JPCLN011
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined mass(es) in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN042, dtype: bool
# JPCLN042
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right-sided zone. Focal well defined nodule(s) in the right-sided zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# mastectomy                   True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN038, dtype: bool
# JPCLN038
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right-sided zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# single_pulmonary_nodule    True
# Name: JPCLN092, dtype: bool
# JPCLN092
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# nipple_shadow              True
# patient_rotated            True
# single_pulmonary_nodule    True
# Name: JPCLN024, dtype: bool
# JPCLN024
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN016
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# simple_pneumothorax          True
# single_pulmonary_nodule      True
# Name: JPCLN080, dtype: bool
# JPCLN080
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right-sided zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN018
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                             True
# unfolded_aorta                           True
# aortic_arch_calcification                True
# interstitial_thickening_diffuse          True
# interstitial_thickening_upper            True
# interstitial_thickening_volloss_upper    True
# single_pulmonary_mass                    True
# single_pulmonary_nodule                  True
# Name: JPCLN003, dtype: bool
# JPCLN003
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Upper zone predominant bilateral reticular changes without volume loss. Bilateral upper zone predominant fibrotic changes with volume loss. Focal well defined mass(es) in the left upper zone. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# single_pulmonary_nodule    True
# Name: JPCLN039, dtype: bool
# JPCLN039
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# single_pulmonary_mass        True
# single_pulmonary_nodule      True
# Name: JPCLN010, dtype: bool
# JPCLN010
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined mass(es) in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta           True
# peribronchial_cuffing    True
# Name: JPCNN005, dtype: bool
# JPCNN005
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                             True
# unfolded_aorta                           True
# focal_airspace_opacity                   True
# interstitial_thickening_upper            True
# interstitial_thickening_volloss_upper    True
# single_pulmonary_nodule                  True
# Name: JPCLN037, dtype: bool
# JPCLN037
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Upper zone predominant right reticular changes without volume loss. Right upper zone predominant fibrotic changes with volume loss. Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                       True
# unfolded_aorta                     True
# aortic_arch_calcification          True
# cardiac_valve_prosthesis           True
# interstitial_thickening_diffuse    True
# mediastinal_clips                  True
# pulmonary_congestion               True
# sternotomy_wires                   True
# Name: JPCNN007, dtype: bool
# JPCNN007
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac valve prosthesis in situ. Cardiac silhouette is enlarged. Surgical clips project over the mediastinum. Sternotomy wires noted. Aorta is tortuous.
#
# Lung parenchyma:	Upper zone venous diversion indicating pulmonary congestion.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta    True
# hyperinflation    True
# Name: JPCNN020, dtype: bool
# JPCNN020
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                       True
# unfolded_aorta                     True
# aortic_arch_calcification          True
# diaphragmatic_eventration          True
# interstitial_thickening_diffuse    True
# single_pulmonary_mass              True
# single_pulmonary_nodule            True
# Name: JPCLN012, dtype: bool
# JPCLN012
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined mass(es) in the right lower zone. Focal well defined nodule(s) in the right lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# nipple_shadow                True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCNN009, dtype: bool
# JPCNN009
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# hyperinflation               True
# multiple_pulmonary_masses    True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN001, dtype: bool
# JPCLN001
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Multiple lung lesions noted in the left lung. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# hyperinflation               True
# linear_atelectasis           True
# patient_rotated              True
# peribronchial_cuffing        True
# Name: JPCLN028, dtype: bool
# JPCLN028
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Atelectasis noted in the left lower lung. Focal airspace opacity in the left upper and bilateral lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCLN082
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# patient_rotated              True
# peribronchial_cuffing        True
# Name: JPCLN052, dtype: bool
# JPCLN052
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                 True
# aortic_arch_calcification      True
# focal_airspace_opacity         True
# hyperinflation                 True
# multifocal_airspace_opacity    True
# single_pulmonary_nodule        True
# Name: JPCLN026, dtype: bool
# JPCLN026
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multifocal airspace opacities in the right lung. Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN014
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# calcified_granuloma          True
# focal_airspace_opacity       True
# hyperinflation               True
# single_pulmonary_nodule      True
# Name: JPCLN007, dtype: bool
# JPCLN007
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper and left lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# Name: JPCLN054, dtype: bool
# JPCLN054
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# peribronchial_cuffing        True
# single_pulmonary_nodule      True
# Name: JPCLN073, dtype: bool
# JPCLN073
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left-sided zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN009, dtype: bool
# JPCLN009
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN012
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# patient_rotated            True
# single_pulmonary_nodule    True
# Name: JPCLN020, dtype: bool
# JPCLN020
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                 True
# aortic_arch_calcification      True
# focal_airspace_opacity         True
# hyperinflation                 True
# multifocal_airspace_opacity    True
# patient_rotated                True
# peribronchial_cuffing          True
# Name: JPCLN033, dtype: bool
# JPCLN033
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multifocal airspace opacities in the right lung. Focal airspace opacity in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta     True
# hyperinflation     True
# patient_rotated    True
# Name: JPCNN001, dtype: bool
# JPCNN001
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                     True
# aortic_arch_calcification          True
# hilar_lymphadenopathy              True
# interstitial_thickening_diffuse    True
# interstitial_thickening_upper      True
# peribronchial_cuffing              True
# single_pulmonary_mass              True
# single_pulmonary_nodule            True
# Name: JPCLN014, dtype: bool
# JPCLN014
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Diffuse left fibrotic changes with preserved lung volume. Upper zone predominant bilateral reticular changes without volume loss. Focal well defined mass(es) in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                       True
# unfolded_aorta                     True
# aortic_arch_calcification          True
# hyperinflation                     True
# interstitial_thickening_diffuse    True
# peribronchial_cuffing              True
# Name: JPCLN047, dtype: bool
# JPCLN047
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                     True
# aortic_arch_calcification          True
# calcified_hilar_lymphadenopathy    True
# calcified_neck_nodes               True
# focal_airspace_opacity             True
# hyperinflation                     True
# multifocal_airspace_opacity        True
# simple_effusion                    True
# single_pulmonary_nodule            True
# Name: JPCLN045, dtype: bool
# JPCLN045
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multifocal airspace opacities in the right lung. Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper and left lower zone.
#
# Pleural space:
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# diaphragmatic_elevation      True
# diaphragmatic_eventration    True
# distended_bowel              True
# focal_airspace_opacity       True
# single_pulmonary_nodule      True
# Name: JPCLN016, dtype: bool
# JPCLN016
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	Distended bowel loops seen in the imaged upper abdomen.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# focal_airspace_opacity     True
# nipple_shadow              True
# single_pulmonary_nodule    True
# Name: JPCLN031, dtype: bool
# JPCLN031
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left upper zone. Focal well defined nodule(s) in the left-sided zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# peribronchial_cuffing        True
# pericardial_fat_pad          True
# Name: JPCNN003, dtype: bool
# JPCNN003
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                           True
# focal_airspace_opacity                   True
# hyperinflation                           True
# incompletely_imaged                      True
# interstitial_thickening_upper            True
# interstitial_thickening_volloss_upper    True
# peribronchial_cuffing                    True
# single_pulmonary_nodule                  True
# Name: JPCLN018, dtype: bool
# JPCLN018
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Lungs are incompletely imaged.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Upper zone predominant bilateral reticular changes without volume loss. Right upper zone predominant fibrotic changes with volume loss. Focal airspace opacity in the right upper and left lower zone. Focal well defined nodule(s) in the left lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# focal_airspace_opacity     True
# single_pulmonary_nodule    True
# Name: JPCLN062, dtype: bool
# JPCLN062
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left-sided zone. Focal well defined nodule(s) in the left upper and right lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# focal_airspace_opacity     True
# incompletely_imaged        True
# single_pulmonary_nodule    True
# Name: JPCLN058, dtype: bool
# JPCLN058
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Lungs are incompletely imaged.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left-sided zone. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# peribronchial_cuffing        True
# simple_effusion              True
# Name: JPCNN010, dtype: bool
# JPCNN010
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:
#
# Pleural space:
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# single_pulmonary_nodule      True
# Name: JPCLN071, dtype: bool
# JPCLN071
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                   True
# aortic_arch_calcification        True
# focal_airspace_opacity           True
# hyperinflation                   True
# interstitial_thickening_upper    True
# peribronchial_cuffing            True
# single_pulmonary_nodule          True
# Name: JPCLN086, dtype: bool
# JPCLN086
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Upper zone predominant right reticular changes without volume loss. Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                     True
# unfolded_aorta                   True
# aortic_arch_calcification        True
# focal_airspace_opacity           True
# interstitial_thickening_upper    True
# linear_atelectasis               True
# patient_rotated                  True
# scoliosis                        True
# single_pulmonary_nodule          True
# Name: JPCLN005, dtype: bool
# JPCLN005
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Upper zone predominant left reticular changes without volume loss. Atelectasis noted in the left-sided lung. Focal airspace opacity in the left upper zone. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# focal_airspace_opacity     True
# single_pulmonary_nodule    True
# Name: JPCLN019, dtype: bool
# JPCLN019
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# diaphragmatic_eventration    True
# hyperinflation               True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN030, dtype: bool
# JPCLN030
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN002
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# simple_effusion              True
# Name: JPCLN059, dtype: bool
# JPCLN059
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone.
#
# Pleural space:
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN011
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# hyperinflation               True
# nipple_shadow                True
# single_pulmonary_nodule      True
# Name: JPCLN023, dtype: bool
# JPCLN023
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal well defined nodule(s) in the right lower zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# JPCNN013
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Satisfactory image quality.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	No significant parenchymal lung abnormality.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# focal_airspace_opacity       True
# hyperinflation               True
# nipple_shadow                True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN021, dtype: bool
# JPCLN021
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left upper zone. Focal well defined nodule(s) in the bilateral upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# cardiomegaly                 True
# unfolded_aorta               True
# aortic_arch_calcification    True
# diaphragmatic_eventration    True
# focal_airspace_opacity       True
# hyperinflation               True
# patient_rotated              True
# single_pulmonary_nodule      True
# Name: JPCLN085, dtype: bool
# JPCLN085
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Cardiac silhouette is enlarged. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta               True
# aortic_arch_calcification    True
# diaphragmatic_eventration    True
# focal_airspace_opacity       True
# hyperinflation               True
# patient_rotated              True
# scoliosis                    True
# single_pulmonary_nodule      True
# Name: JPCLN046, dtype: bool
# JPCLN046
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the left upper zone. Focal well defined nodule(s) in the left upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:
#
# Other:
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta             True
# focal_airspace_opacity     True
# patient_rotated            True
# single_pulmonary_nodule    True
# Name: JPCLN015, dtype: bool
# JPCLN015
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Aorta is tortuous.
#
# Lung parenchyma:	Focal airspace opacity in the right upper and bilateral lower zone. Focal well defined nodule(s) in the right-sided zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
# unfolded_aorta                 True
# aortic_arch_calcification      True
# focal_airspace_opacity         True
# hyperinflation                 True
# multifocal_airspace_opacity    True
# patient_rotated                True
# peribronchial_cuffing          True
# single_pulmonary_nodule        True
# Name: JPCLN032, dtype: bool
# JPCLN032
# Title	CHEST X-RAY
#
# Projection:	Frontal chest radiograph.
#
# Findings:
# Technical quality:	Patient rotation noted.
#
# Lines and Tubes:	No lines or tubes identified.
#
# Cardiomediastinal:	Thoracic aortic calcification demonstrated. Aorta is tortuous.
#
# Lung parenchyma:	Multifocal airspace opacities in the right lung. Focal airspace opacity in the right upper zone. Focal well defined nodule(s) in the right upper zone.
#
# Pleural space:	Normal pleural spaces.
#
# Bones:	No bony abnormality.
#
# Other:	No other findings.
#
# Conclusion:	[Empty field]
# *******************************
